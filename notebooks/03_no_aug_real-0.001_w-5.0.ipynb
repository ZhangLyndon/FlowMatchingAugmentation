# %% [markdown]
# # Synthetic Data Augmentation with Conditional Flow Matching
#
# ## Part 3
#
# In this section, we evaluate the impact of incorporating synthetic image data on classification performance. In particular, we examine changes in classification accuracy and score when the Fashion MNIST dataset is augmented with synthetic samples in the extremely low-data regime, using 0.1% of the available data for model training.

# %% [markdown]
# ## Setup

# %%
# !find . -mindepth 1 -exec rm -rf {} + &> /dev/null
# !git clone https://github.com/ZhangLyndon/FlowMatchingAugmentation . > /dev/null 2>&1

# %%
# !pip install -qU pip
# !pip install -qU -r requirements.txt

# %%
import os
import sys
import argparse
import functools

# Silence tqdm output
os.environ["TQDM_DISABLE"] = "1"

# Reduce CUDA memory fragmentation
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"

# %%
import torch
import torchvision
import numpy as np

# Components for initializing an ImageNet-pretrained ResNet-18 classifier, fine-
# tuning it on Fashion MNIST, and evaluating classification performance on base-
# line, low-data, and synthetically augmented settings.
from classification import (ClassificationTrainer,
                            create_classifier, ResNetClassifier,
                            SyntheticDataGenerator, SyntheticAugmentationEvaluator,
                            create_augmented_dataset)

# Utilities for loading the Fashion MNIST dataset, computing top-k categorical
# accuracy and average cross-entropy loss, and saving training results.
from utils import get_dataloaders, AverageMeter, accuracy, save_results

import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams["font.family"] = "DejaVu Sans Mono"

# %% [markdown]
# We assess the performance impact of synthetic augmentation in the extremely low-data regime (using 0.1% of the training set), and begin by evaluating the classification performance of the unaugmented training split, measuring both accuracy and the macro $\mathsf F_1$ score.

# %%
# Configure augmentation evaluation pipeline
augmentation_args = argparse.Namespace(data_root = "./data",
                                       batch_size = 16,
                                       num_workers = 0,
                                       epochs = 25,
                                       lr = 0.001,
                                       weight_decay = 1e-4,
                                       step_size = 15,
                                       gamma = 0.1,
                                       synthetic_data_dir = "./images",
                                       real_ratio = 0.001,
                                       classification_dir = "./results/classification",
                                       augmentation_dir = "./results/augmentation",
                                       checkpoint_dir = "./checkpoints",
                                       save_interval = 20,
                                       seed = 42)

# Create directory to store synthetic augmentation results
os.makedirs(augmentation_args.augmentation_dir, exist_ok = True)

# Set random seed for reproducibility
torch.manual_seed(augmentation_args.seed)
np.random.seed(augmentation_args.seed)

# %%
guidance_scale = 5.0
evaluator = SyntheticAugmentationEvaluator(augmentation_args, guidance_scale)
evaluator.run_low_data_experiments(augmentation_args.real_ratio, False)
# Out:
# Number of epochs: 25
# Number of training samples: 60
# Number of validation samples: 10000
# Epoch 1/25
# Training Set | Loss: 2.6464, Top-1 Accuracy: 15.00%, Top-5 Accuracy: 60.00%
# Validation Set | Loss: 3.1730, Top-1 Accuracy: 10.42%, Top-5 Accuracy: 60.25%
# Best Validation Loss (Up Until Now): 3.1730
# _________________________________________________________________________________________________________
#
# Epoch 2/25
Top-1 Accuracy: 85.00%, Top-5 Accuracy: 98.33%
# Validation Set | Loss: 1.8681, Top-1 Accuracy: 57.28%, Top-5 Accuracy: 86.62%
# Best Validation Loss (Up Until Now): 1.8458
# _________________________________________________________________________________________________________
#
# Epoch 18/25
# Training Set | Loss: 0.4659, Top-1 Accuracy: 81.67%, Top-5 Accuracy: 98.33%
# Validation Set | Loss: 1.7869, Top-1 Accuracy: 57.21%, Top-5 Accuracy: 86.05%
# Best Validation Loss (Up Until Now): 1.7869
# _________________________________________________________________________________________________________
#
# Epoch 19/25
# Training Set | Loss: 0.4020, Top-1 Accuracy: 85.00%, Top-5 Accuracy: 98.33%
# Validation Set | Loss: 1.7032, Top-1 Accuracy: 57.19%, Top-5 Accuracy: 85.36%
# Best Validation Loss (Up Until Now): 1.7032
# _________________________________________________________________________________________________________
#
# Epoch 20/25
# Training Set | Loss: 0.1639, Top-1 Accuracy: 96.67%, Top-5 Accuracy: 100.00%
# Validation Set | Loss: 1.7123, Top-1 Accuracy: 56.86%, Top-5 Accuracy: 85.36%
# Best Validation Loss (Up Until Now): 1.7032
# _________________________________________________________________________________________________________
#
# Epoch 21/25
# Training Set | Loss: 0.2985, Top-1 Accuracy: 85.00%, Top-5 Accuracy: 100.00%
# Validation Set | Loss: 1.7340, Top-1 Accuracy: 57.28%, Top-5 Accuracy: 85.54%
# Best Validation Loss (Up Until Now): 1.7032
# _________________________________________________________________________________________________________
#
# Epoch 22/25
# Training Set | Loss: 0.2756, Top-1 Accuracy: 90.00%, Top-5 Accuracy: 100.00%
# Validation Set | Loss: 1.7251, Top-1 Accuracy: 57.08%, Top-5 Accuracy: 85.34%
# Best Validation Loss (Up Until Now): 1.7032
# _________________________________________________________________________________________________________
#
# Epoch 23/25
# Training Set | Loss: 0.2488, Top-1 Accuracy: 93.33%, Top-5 Accuracy: 100.00%
# Validation Set | Loss: 1.7318, Top-1 Accuracy: 57.10%, Top-5 Accuracy: 85.16%
# Best Validation Loss (Up Until Now): 1.7032
# _________________________________________________________________________________________________________
#
# Epoch 24/25
# Training Set | Loss: 0.2026, Top-1 Accuracy: 95.00%, Top-5 Accuracy: 100.00%
# Validation Set | Loss: 1.6952, Top-1 Accuracy: 57.60%, Top-5 Accuracy: 84.98%
# Best Validation Loss (Up Until Now): 1.6952
# _________________________________________________________________________________________________________
#
# Epoch 25/25
# Training Set | Loss: 0.1780, Top-1 Accuracy: 95.00%, Top-5 Accuracy: 100.00%
# Validation Set | Loss: 1.7033, Top-1 Accuracy: 57.88%, Top-5 Accuracy: 85.23%
# Best Validation Loss (Up Until Now): 1.6952
# _________________________________________________________________________________________________________
#
# Training Time: 114.68 seconds
# Best Validation Loss (All Epochs): 1.6952
# Real Data Ratio: 0.001, Guidance Scale: 5.0
# Unaugmented Evaluation: {'accuracy': 57.88, 'f1_macro': 0.556444646416117, 'total_samples': 10000}

# %% [markdown]
# Prior to applying augmentation to the extremely low-data training split (i.e., 0.1% of the training set), the model achieves a classification accuracy of $57.88\%$, a macro $\mathsf F_1$ score of $0.5564$, and an optimal validation (cross-entropy) loss of $1.6952$ at epoch 24.
